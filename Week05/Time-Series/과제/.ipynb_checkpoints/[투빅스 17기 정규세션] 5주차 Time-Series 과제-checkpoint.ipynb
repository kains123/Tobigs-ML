# %%
import pandas as pd

data = pd.read_csv('kingage_with_date.csv', index_col = 0)
data.head()
# Out:
#             age
# date
# 1981-01-01   60
# 1982-01-01   43
# 1983-01-01   67
# 1984-01-01   50
# 1985-01-01   56

# %% [markdown]
# ## 1. 모형 식별

# %%
# Line plots of time series
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(6,3))
fig.suptitle('Time Series Data')
data.plot(ax=ax)
plt.show()
#Historgram
fig, ax = plt.subplots(figsize=(6,3))
fig.suptitle('Histogram')
data.hist(ax=ax)
plt.show()

# %%
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

plot_acf(data)
plot_pacf(data)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# 차분(Differencing) : 현 시점 데이터에서, d 시점 이전 데이터를 뺀 것

diff_1= data.diff(periods=1).iloc[1:]
diff_1.plot()
plot_acf(diff_1)
plot_pacf(diff_1)
plt.show()

# %% [markdown]
# - MA(1)

# %% [markdown]
# ## 2. 모수 추정

# %%
# 1) SARIMA (1, 1, 1) x (1,1,1,12) : fit1
# 2) SARIMA (0, 1, 1) x (1,1,1,12) : fit2
# 3) SARIMA (0, 1, 2) x (1,1,1,12) : fit3

# %%
# fit an ARIMA model and plot residual errors
from pandas import datetime
from pandas import read_csv
from pandas import DataFrame
from statsmodels.tsa.arima.model import ARIMA
from matplotlib import pyplot

# fit model
model = ARIMA(data, order=(0,1,1), seasonal_order=(1,1,1,12))
model_fit = model.fit()
# summary of fit model
print(model_fit.summary())
# line plot of residuals
residuals = DataFrame(model_fit.resid)
residuals.plot()
pyplot.show()
# density plot of residuals
residuals.plot(kind='kde')
pyplot.show()
# summary stats of residuals

print(residuals.describe())

#SARIMA (1, 1, 1) x (1,1,1,12) : fit1 -> AIC = 264.465
#SARIMA (0, 1, 1) x (1,1,1,12) : fit2 -> AIC = 262.710
#SARIMA (0, 1, 2) x (1,1,1,12) : fit2 -> AIC = 264.325
#AIC가 가장 작은 (0, 1, 1)로 한다.
# Out:
# /Users/yejinlee/opt/anaconda3/envs/practice_tensorflow/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#
# /Users/yejinlee/opt/anaconda3/envs/practice_tensorflow/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:527: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# /Users/yejinlee/opt/anaconda3/envs/practice_tensorflow/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:527: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# /Users/yejinlee/opt/anaconda3/envs/practice_tensorflow/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:527: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# ...

# %%
from statsmodels.tsa.stattools import adfuller
result = adfuller(data['age'])
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Test Statistics Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -4.090230
# p-value: 0.001005
# Critical Test Statistics Values:
# 	1%: -3.601
# 	5%: -2.935
# 	10%: -2.606

# %% [markdown]
# ## 3. 모형 적합성 진단

# %%
from statsmodels.tsa.arima_model import ARIMA

model = ARIMA(data, order=(0,1,1))
model_fit = model.fit(trend='nc',full_output=True, disp=1)
print(model_fit.summary())
# Out:
#                              ARIMA Model Results
# ...
# Dep. Variable:                  D.age   No. Observations:                   41
# Model:                 ARIMA(0, 1, 1)   Log Likelihood                -170.064
# Method:                       css-mle   S.D. of innovations             15.180
# Date:                Tue, 01 Mar 2022   AIC                            344.128
# Time:                        21:57:51   BIC                            347.555
# Sample:                    01-01-1982   HQIC                           345.376
#                          - 01-01-2022
# ...
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# ma.L1.D.age    -0.7218      0.121     -5.976      0.000      -0.958      -0.485
#                                     Roots
# ...
#                   Real          Imaginary           Modulus         Frequency
# ...

# %%
model_fit.plot_predict()

# %% [markdown]
# ## 4. 모형 확정 및 예측 (예측값 17개 출력하기)

# %%
# evaluate an ARIMA model using a walk-forward validation
from pandas import read_csv
from pandas import datetime
from matplotlib import pyplot
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error
from math import sqrt


X = data['age']
size = 17
train, test = X[0:size], X[size:len(X)]
history = [x for x in train]
predictions = list()
# walk-forward validation
for t in range(len(test)):
	model = ARIMA(history, order=(0,1,1))
	model_fit = model.fit()
	output = model_fit.forecast()
	yhat = output[0]
	predictions.append(yhat)
	obs = test[t]
	history.append(obs)
	print('predicted=%f, expected=%f' % (yhat, obs))
# evaluate forecasts
rmse = sqrt(mean_squared_error(test, predictions))
print('Test RMSE: %.3f' % rmse)
# plot forecasts against actual outcomes
pyplot.plot(test)
pyplot.plot(predictions, color='red')
pyplot.show()
# Out:
# /Users/yejinlee/opt/anaconda3/envs/practice_tensorflow/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# predicted=33.871155, expected=35.000000
# predicted=34.456011, expected=53.000000
# predicted=40.781300, expected=56.000000
# predicted=44.486970, expected=16.000000
# predicted=38.097587, expected=43.000000
# predicted=39.399795, expected=69.000000
# predicted=45.253276, expected=59.000000
# predicted=47.563026, expected=48.000000
# predicted=47.598170, expected=59.000000
# predicted=50.097379, expected=86.000000
# predicted=62.848894, expected=55.000000
# predicted=59.547744, expected=68.000000
# predicted=62.353279, expected=51.000000
# predicted=58.820102, expected=33.000000
# predicted=52.507056, expected=49.000000
# ...
